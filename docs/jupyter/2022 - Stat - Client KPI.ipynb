# %% [markdown]
# ## Notebook dedicated to Client's stats
#
#
# • store the proper data into cloud database
# • fetch the needed data and calc the client's stats for a given cliend_id

# %%
import pandas as pd
import math
import pprint
data = pd.read_csv('/Users/jonathankhalifa/Desktop/T-DAT-901/KaDo.csv')
pd.options.mode.chained_assignment = None  # default='warn'

data.head(20)
# Out:
#     TICKET_ID  MOIS_VENTE  PRIX_NET          FAMILLE  \
# 0    35592159          10      1.67          HYGIENE
# 1    35592159          10      1.66          HYGIENE
# 2    35592159          10      7.45  SOINS DU VISAGE
# 3    35592159          10      5.95  SOINS DU VISAGE
# 4    35592159          10      1.67          HYGIENE
# 5    35509899           9     13.00        PARFUMAGE
# 6    35509899           9      5.50   SOINS DU CORPS
# 7    36417517          12      1.75          HYGIENE
# 8    36417517          12      1.76          HYGIENE
# 9    36417517          12      2.25          HYGIENE
# 10   36417517          12      5.63   SOINS DU CORPS
# 11   36417517          12      4.02   SOINS DU CORPS
# 12   36417517          12     11.04        PARFUMAGE
# 13   36417517          12     10.55        PARFUMAGE
# 14   33002894           1      7.45       MAQUILLAGE
# 15   33064616           1      5.45  SOINS DU VISAGE
# 16   33064616           1      1.25   SOINS DU CORPS
# 17   33534570           3      2.45          HYGIENE
# 18   33534570           3      2.95      CAPILLAIRES
# 19   33534570           3      1.65       MAQUILLAGE
#
#                            UNIVERS                       MAILLE  \
# 0           HYG_DOUCHE JARDINMONDE                      HYG_JDM
# 1           HYG_DOUCHE JARDINMONDE                      HYG_JDM
# 2      VIS_CJOUR Jeunes Specifique           VIS_JEUNE_ET_LEVRE
# 3                   VIS_DEMAQ AAAR         VIS_AAAR_DEMAQLOTION
# 4           HYG_DOUCHE JARDINMONDE                      HYG_JDM
# 5                PARF_EAUX PARFUMS                  PARF_PARFUM
# 6   CORPS_LAIT HUILE PLAISIRNATURE        CORPS_HYDR_LAIT_HUILE
# 7               HYG_DOUCHE PARFUMS                 HYG_PARFUMEE
# 8               HYG_DOUCHE PARFUMS                 HYG_PARFUMEE
# 9               HYG_DOUCHE PARFUMS                 HYG_PARFUMEE
# 10        CORPS_LAIT HUILE PARFUMS        CORPS_HYDR_LAIT_HUILE
# 11        CORPS_LAIT HUILE PARFUMS        CORPS_HYDR_LAIT_HUILE
# 12               PARF_EAUX PARFUMS                  PARF_PARFUM
# 13               PARF_EAUX PARFUMS                  PARF_PARFUM
# 14           MAQ_LEV RAL Brillance              MAQ_LEV_RAL_HMG
# 15     VIS_CJOUR Jeunes Specifique           VIS_JEUNE_ET_LEVRE
# 16            CORPS_SOIN DES MAINS  CORPS_HYDRA_NOURRI_ET_SOINS
# 17              HYG_DOUCHE PARFUMS                 HYG_PARFUMEE
# 18                    CAP_AP SHAMP             CAPILLAIRE_AUTRE
# 19              MAQ_ONG Vernis LUM                   MAQ_ONGLES
#
#                                    LIBELLE    CLI_ID
# 0            GD JDM4 PAMPLEMOUSSE FL 200ML   1490281
# 1            GD JDM4 PAMPLEMOUSSE FL 200ML   1490281
# 2          CR JR PARF BIO.SPE AC.SENT.50ML   1490281
# 3            EAU MICELLAIRE 3 THES FL200ML   1490281
# 4                   GD JDM4 TIARE FL 200ML   1490281
# 5   EDT  UN MATIN AU JARDIN  100ML  MUGUET  13290776
# 6              LAIT VELOUTE COCO PN2 400ML  13290776
# 7                      GD LILAS FP FL200ML  13290776
# 8                      GD LILAS FP FL200ML  13290776
# 9                      GD LILAS FP FL200ML  13290776
# 10                   LAIT LILAS FP FL200ML  13290776
# 11                   LAIT LILAS FP FL200ML  13290776
# 12      EDT UN MATIN AU JARDIN 100ML LILAS  13290776
# 13      EDT UN MATIN AU JARDIN 100ML LILAS  13290776
# 14          RAL BRILLANC GEL/PRALIN CN3 2G  20163348
# 15          CR JOUR PX/MIX HYDRA/VEG P50ML  20200041
# 16        CREME MAINS CACAO ET ORANGE 75ML  20200041
# 17                 GD AGRUMES FP FL 200 ML  20561854
# 18  LISSAGE AP SHAMPOING LISSANT 150ML SVC  20561854
# 19            VAO CERISE NOIRE 32 LUM4 3ML  20561854

# %% [markdown]
# # In order to insert client data into cloud DB
#
# - has already been ran, no need to run again

# %%
'''
import pymongo

# get list of all unique client ids
cliList = data['CLI_ID'].unique()

# conn string
client = pymongo.MongoClient("mongodb+srv://dat:dat@clusterdat2.afein.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
db = client['datdb']
dataset = db['groupbyCli']


# group clients by client id
d = data.groupby('CLI_ID')


# RUN ONLY ONCE
# foreach group , insert in df
for cliId in cliList:
    dd = d.get_group(cliId)
    dd = dd.astype('str')
    dd.index = dd.index.astype('str')
    dd = dd.to_dict('dict')
    x = dataset.insert_one(dd)
'''
# Out:
# '\nimport pymongo\n\n# get list of all unique client ids\ncliList = data[\'CLI_ID\'].unique()\n\n# conn string\nclient = pymongo.MongoClient("mongodb+srv://dat:dat@clusterdat2.afein.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")\ndb = client[\'datdb\']\ndataset = db[\'groupbyCli\']\n\n\n# group clients by client id\nd = data.groupby(\'CLI_ID\')\n\n\n# RUN ONLY ONCE\n# foreach group , insert in df\nfor cliId in cliList:\n    dd = d.get_group(cliId)\n    dd = dd.astype(\'str\')\n    dd.index = dd.index.astype(\'str\')\n    dd = dd.to_dict(\'dict\')\n    x = dataset.insert_one(dd)\n'

# %% [markdown]
# # Func to be used in backend api in order to fetch client data and calc it's KPIs.
# - User ID
# - User ticket_ids
# - Total nb of carts
# - Total expenses
# - Most expensive cart
# - Least expensive cart
# - Average cart price
# - Most expensive product bought
# - Expenses per month
# - Nb of carts per month
# - Purchace frequency per product
# - Purchace frequency per maille
# - Purchace frequency per univers
# - Purchace frequency per famille
# - Gender supposition

# %%
import pandas as pd
import math
import pprint
import pymongo

def get_user_data2 (user_id):

    client = pymongo.MongoClient("mongodb+srv://dat:dat@clusterdat2.afein.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
    db = client['datdb']
    collection = db['groupbyCli']
    cursor = collection.find_one({'CLI_ID.0': user_id})
    resultDf = pd.DataFrame(cursor)
    
    
    result = {}
    resultDf['PRIX_NET'] = resultDf['PRIX_NET'].apply(float)
    resultDf['TICKET_ID'] = resultDf['TICKET_ID'].apply(int)
    user_tickets = resultDf['TICKET_ID'].unique()
    cart_tot = resultDf.groupby("TICKET_ID").sum()
    #return cart_tot
    result['cli_id'] = user_id
    
    result['ticket_ids'] = user_tickets

    nb_tot_paniers = len(user_tickets)
    result['nb_tot_paniers'] = nb_tot_paniers

    total_depenses = resultDf['PRIX_NET'].sum()
    result['total_depenses'] = total_depenses # "%.2f" %

    prix_panier_max = cart_tot['PRIX_NET'].max()
    result['prix_panier_max'] = prix_panier_max

    prix_panier_min = cart_tot['PRIX_NET'].min()
    result['prix_panier_min'] = prix_panier_min

    prix_article_achete_max = resultDf['PRIX_NET'].max()
    result['prix_article_achete_max'] = prix_article_achete_max

    depenses_par_moi = resultDf[['MOIS_VENTE', 'PRIX_NET']].groupby("MOIS_VENTE").sum()
    result['depenses_par_moi'] = depenses_par_moi

    prix_panier_moy = cart_tot['PRIX_NET'].mean()
    result['prix_panier_moy'] = "%.2f" % prix_panier_moy

    nb_paniers_par_moi = resultDf[['MOIS_VENTE', 'TICKET_ID']].groupby("MOIS_VENTE").nunique()
    nb_paniers_par_moi.drop(nb_paniers_par_moi.columns[0], axis=1, inplace=True)
    result['nb_paniers_par_moi'] = nb_paniers_par_moi

    top_ten_produits_achetes = resultDf['LIBELLE'].value_counts()
    result['top_ten_produits_achetes'] = top_ten_produits_achetes

    top_maille_achetes = resultDf['MAILLE'].value_counts()
    result['top_maille_achetes'] = top_maille_achetes

    top_famille_achetes = resultDf['FAMILLE'].value_counts()
    result['top_famille_achetes'] = top_famille_achetes

    top_univers_achetes = resultDf['UNIVERS'].value_counts()
    result['top_univers_achetes'] = top_univers_achetes
    
    if top_famille_achetes.max() == top_famille_achetes.get('MAQUILLAGE'):
        gender_supposition = 'FEMALE'
    elif top_famille_achetes.get('MAQUILLAGE') == 'None':
        gender_supposition = 'MALE'
    else:
        gender_supposition = 'UNKNOWN'
    result['gender_supposition'] = gender_supposition
    
    
    return result

# %% [markdown]
# # Test with cliend id n° 1490281

# %%
x = get_user_data2('1490281')
x
# Out:
# {'cli_id': '1490281',
#  'ticket_ids': array([35592159]),
#  'nb_tot_paniers': 1,
#  'total_depenses': 18.4,
#  'prix_panier_max': 18.4,
#  'prix_panier_min': 18.4,
#  'prix_article_achete_max': 7.45,
#  'depenses_par_moi':             PRIX_NET
#  MOIS_VENTE
#  10              18.4,
#  'prix_panier_moy': '18.40',
#  'nb_paniers_par_moi':             TICKET_ID
#  MOIS_VENTE
#  10                  1,
#  'top_ten_produits_achetes': GD JDM4 PAMPLEMOUSSE FL 200ML      2
#  EAU MICELLAIRE 3 THES FL200ML      1
#  CR JR PARF BIO.SPE AC.SENT.50ML    1
#  GD JDM4 TIARE FL 200ML             1
#  Name: LIBELLE, dtype: int64,
#  'top_maille_achetes': HYG_JDM                 3
#  VIS_AAAR_DEMAQLOTION    1
#  VIS_JEUNE_ET_LEVRE      1
#  Name: MAILLE, dtype: int64,
#  'top_famille_achetes': HYGIENE            3
#  SOINS DU VISAGE    2
#  Name: FAMILLE, dtype: int64,
#  'top_univers_achetes': HYG_DOUCHE JARDINMONDE         3
#  VIS_CJOUR Jeunes Specifique    1
#  VIS_DEMAQ AAAR                 1
#  Name: UNIVERS, dtype: int64,
#  'gender_supposition': 'UNKNOWN'}
